# %% [markdown]
# ## 1. Import du Dataset from Roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="GBbY0P8ZuDM8EocauwAB")
project = rf.workspace("visionqai").project("detection-defauts-3ikxt")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (1.2.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2025.11.12)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.1.1)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.60.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.4)
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ## 2. Import du Modèle from Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/best.pt')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.3.233)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
# Prédire sur ton dossier de validation
results = model.predict(source='/content/Détection-défauts-2/valid/images', save=True)
# Out:
# image 1/20 /content/Détection-défauts-2/valid/images/IMG_0884_JPG.rf.b26491192cd331bb7e70573be33144db.jpg: 640x640 2 cable 2s, 24.5ms
# image 2/20 /content/Détection-défauts-2/valid/images/IMG_0891_JPG.rf.82ac1219ad20cee78e0758d6a96e0e99.jpg: 640x640 1 cable 2, 15.3ms
# image 3/20 /content/Détection-défauts-2/valid/images/photo-1761661075325_jpg.rf.ad5962f4df803ed77c3b63140114418e.jpg: 640x640 1 cable 2, 42.0ms
# image 4/20 /content/Détection-défauts-2/valid/images/photo-1761661091891_jpg.rf.19e25e4c5f7dc226851b562525081395.jpg: 640x640 1 cable 2, 37.0ms
# image 5/20 /content/Détection-défauts-2/valid/images/photo-1761661325771_jpg.rf.5b9d65fbd9258091884393ca6595982e.jpg: 640x640 1 cable 2, 26.1ms
# image 6/20 /content/Détection-défauts-2/valid/images/photo-1761661484246_jpg.rf.b577cc05964bd5f09807e12977624af8.jpg: 640x640 1 cable 2, 44.6ms
# image 7/20 /content/Détection-défauts-2/valid/images/photo-1761661508569_jpg.rf.9231e77d6c659237c1b01cf2b5565f25.jpg: 640x640 1 cable 2, 41.6ms
# image 8/20 /content/Détection-défauts-2/valid/images/photo-1761661530556_jpg.rf.2d4a3e665efa8921c1a6153816ca74ba.jpg: 640x640 1 cable 2, 22.9ms
# image 9/20 /content/Détection-défauts-2/valid/images/photo-1761661547283_jpg.rf.abf2cf093ba33b11e82d34e6804106bf.jpg: 640x640 1 cable 2, 41.2ms
# image 10/20 /content/Détection-défauts-2/valid/images/photo-1761661709799_jpg.rf.b48a6a37a16035d3391b5a47345a3015.jpg: 640x640 1 cable 2, 36.6ms
# image 11/20 /content/Détection-défauts-2/valid/images/photo-1761661756025_jpg.rf.1f8afc05ac576c975fb49641ab08af15.jpg: 640x640 1 cable 2, 53.2ms
# image 12/20 /content/Détection-défauts-2/valid/images/photo-1761661788286_jpg.rf.af3cb27a93bf0663162a4a6998a0875c.jpg: 640x640 1 cable 2, 12.8ms
# image 13/20 /content/Détection-défauts-2/valid/images/photo-1761661800233_jpg.rf.381209b6c828ede80f83c5951dd9a384.jpg: 640x640 1 cable 2, 26.2ms
# image 14/20 /content/Détection-défauts-2/valid/images/photo-1761661811597_jpg.rf.1466baa54d93bc5a10dfea0f21591565.jpg: 640x640 1 cable 2, 17.5ms
# image 15/20 /content/Détection-défauts-2/valid/images/photo-1761661847170_jpg.rf.c3f7d5ddc75d4230204dad68308f19f5.jpg: 640x640 1 cable 2, 37.5ms
# image 16/20 /content/Détection-défauts-2/valid/images/photo-1761661958940_jpg.rf.73cba6a4115ed953fcf6c11703ba0fab.jpg: 640x640 1 cable 2, 26.2ms
# image 17/20 /content/Détection-défauts-2/valid/images/photo-1761662048766_jpg.rf.a6de336113b4df322ff95165e318093a.jpg: 640x640 1 cable 2, 25.1ms
# image 18/20 /content/Détection-défauts-2/valid/images/photo-1761662123931_jpg.rf.2260ae9698f0fb51d042ea7b3bd66d7d.jpg: 640x640 1 cable 2, 37.5ms
# image 19/20 /content/Détection-défauts-2/valid/images/photo-1761662163192_jpg.rf.c0ba884f16268edb312b1453c07ee365.jpg: 640x640 2 cable 2s, 29.0ms
# image 20/20 /content/Détection-défauts-2/valid/images/photo-1761662509312_jpg.rf.50fa7060199433bda51760f383fea4ee.jpg: 640x640 2 cable 2s, 10.5ms
# Speed: 6.4ms preprocess, 30.4ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/segment/predict2

# %% [markdown]
# ## 3. Génération des Masques

# %%
import os
import cv2

# Définir les dossiers à traiter
datasets = {
    "train": "/content/Détection-défauts-2/train/images",
    "valid": "/content/Détection-défauts-2/valid/images"
}

# Boucle sur train et valid
for split, images_folder in datasets.items():
    masks_folder = f"/content/dataset_masks/{split}"
    os.makedirs(masks_folder, exist_ok=True)

    for img_name in os.listdir(images_folder):
        img_path = os.path.join(images_folder, img_name)
        results = model(img_path)

        # Vérifier s'il y a des masques détectés
        if results[0].masks is not None and len(results[0].masks.data) > 0:
            # Récupération du masque
            mask = results[0].masks.data[0].cpu().numpy()
            mask = (mask > 0.5).astype("uint8") * 255

            # Enregistrement du masque
            mask_path = os.path.join(masks_folder, img_name.replace(".jpg","_mask.png"))
            cv2.imwrite(mask_path, mask)

            print(f"Masque généré : {mask_path}")
        else:
            print(f"Aucun masque détecté pour : {img_name}")
# Out:
# image 1/1 /content/Détection-défauts-2/train/images/photo-1761661286886_jpg.rf.91ce9f4813d2ab9989a1bb135d394074.jpg: 640x640 1 cable 2, 21.0ms
# Speed: 5.2ms preprocess, 21.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/train/photo-1761661286886_jpg.rf.91ce9f4813d2ab9989a1bb135d394074_mask.png
#
# image 1/1 /content/Détection-défauts-2/train/images/photo-1761661652765_jpg.rf.8cb2a38366ebae840125f6989e36ecb7.jpg: 640x640 1 cable 2, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/train/photo-1761661652765_jpg.rf.8cb2a38366ebae840125f6989e36ecb7_mask.png
#
# image 1/1 /content/Détection-défauts-2/train/images/photo-1761661794293_jpg.rf.24b3af4bfd2689e88f4aee4107d72d3d.jpg: 640x640 1 cable 2, 25.5ms
# Speed: 6.9ms preprocess, 25.5ms inference, 11.2ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/train/photo-1761661794293_jpg.rf.24b3af4bfd2689e88f4aee4107d72d3d_mask.png
#
# image 1/1 /content/Détection-défauts-2/train/images/photo-1761661393641_jpg.rf.cced06cc6a0e1caca28f6b9186d75705.jpg: 640x640 1 cable 2, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/train/photo-1761661393641_jpg.rf.cced06cc6a0e1caca28f6b9186d75705_mask.png
#
# image 1/1 /content/Détection-défauts-2/train/images/photo-1761661252730_jpg.rf.dc23e7018f64eab79187e9e5ecf20549.jpg: 640x640 1 cable 2, 14.1ms
# Speed: 1.9ms preprocess, 14.1ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/train/photo-1761661252730_jpg.rf.dc23e7018f64eab79187e9e5ecf20549_mask.png
#
# image 1/1 /content/Détection-défauts-2/train/images/photo-1761661170177_jpg.rf.1bf16c1f6e0098c88335a61a746d08bf.jpg: 640x640 2 cable 2s, 19.2ms
# Speed: 2.2ms preprocess, 19.2ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/train/photo-1761661170177_jpg.rf.1bf16c1f6e0098c88335a61a746d08bf_mask.png
#
# image 1/1 /content/Détection-défauts-2/train/images/photo-1761661705355_jpg.rf.311f5709b7fe65d08fba4280a0b046be.jpg: 640x640 1 cable 2, 21.9ms
# Speed: 1.8ms preprocess, 21.9ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/train/photo-1761661705355_jpg.rf.311f5709b7fe65d08fba4280a0b046be_mask.png
#
# image 1/1 /content/Détection-défauts-2/train/images/photo-1761
mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761661788286_jpg.rf.af3cb27a93bf0663162a4a6998a0875c.jpg: 640x640 1 cable 2, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761661788286_jpg.rf.af3cb27a93bf0663162a4a6998a0875c_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/IMG_0891_JPG.rf.82ac1219ad20cee78e0758d6a96e0e99.jpg: 640x640 1 cable 2, 11.8ms
# Speed: 2.3ms preprocess, 11.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/IMG_0891_JPG.rf.82ac1219ad20cee78e0758d6a96e0e99_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761662123931_jpg.rf.2260ae9698f0fb51d042ea7b3bd66d7d.jpg: 640x640 1 cable 2, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761662123931_jpg.rf.2260ae9698f0fb51d042ea7b3bd66d7d_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761662509312_jpg.rf.50fa7060199433bda51760f383fea4ee.jpg: 640x640 2 cable 2s, 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761662509312_jpg.rf.50fa7060199433bda51760f383fea4ee_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761661709799_jpg.rf.b48a6a37a16035d3391b5a47345a3015.jpg: 640x640 1 cable 2, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761661709799_jpg.rf.b48a6a37a16035d3391b5a47345a3015_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761661811597_jpg.rf.1466baa54d93bc5a10dfea0f21591565.jpg: 640x640 1 cable 2, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761661811597_jpg.rf.1466baa54d93bc5a10dfea0f21591565_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761662163192_jpg.rf.c0ba884f16268edb312b1453c07ee365.jpg: 640x640 2 cable 2s, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761662163192_jpg.rf.c0ba884f16268edb312b1453c07ee365_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761661484246_jpg.rf.b577cc05964bd5f09807e12977624af8.jpg: 640x640 1 cable 2, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761661484246_jpg.rf.b577cc05964bd5f09807e12977624af8_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761661091891_jpg.rf.19e25e4c5f7dc226851b562525081395.jpg: 640x640 1 cable 2, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761661091891_jpg.rf.19e25e4c5f7dc226851b562525081395_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761662048766_jpg.rf.a6de336113b4df322ff95165e318093a.jpg: 640x640 1 cable 2, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761662048766_jpg.rf.a6de336113b4df322ff95165e318093a_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761661075325_jpg.rf.ad5962f4df803ed77c3b63140114418e.jpg: 640x640 1 cable 2, 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761661075325_jpg.rf.ad5962f4df803ed77c3b63140114418e_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761661847170_jpg.rf.c3f7d5ddc75d4230204dad68308f19f5.jpg: 640x640 1 cable 2, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761661847170_jpg.rf.c3f7d5ddc75d4230204dad68308f19f5_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761661958940_jpg.rf.73cba6a4115ed953fcf6c11703ba0fab.jpg: 640x640 1 cable 2, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761661958940_jpg.rf.73cba6a4115ed953fcf6c11703ba0fab_mask.png
#
# image 1/1 /content/Détection-défauts-2/valid/images/photo-1761661756025_jpg.rf.1f8afc05ac576c975fb49641ab08af15.jpg: 640x640 1 cable 2, 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Masque généré : /content/dataset_masks/valid/photo-1761661756025_jpg.rf.1f8afc05ac576c975fb49641ab08af15_mask.png

# %% [markdown]
# ## 4. Nettoyage des Masques

# %%
from skimage import morphology
from scipy import ndimage as ndi

def preprocess_mask(mask):
    """Nettoyage du masque : fermeture, suppression petits objets, remplissage des trous"""
    mask = mask > 0
    mask = morphology.binary_closing(mask, morphology.disk(2))
    mask = morphology.remove_small_objects(mask, min_size=50)
    mask = ndi.binary_fill_holes(mask)
    return mask.astype(bool)

# %% [markdown]
# ## 5. Squelettisation

# %%
from skimage.morphology import skeletonize

def skeletonize_mask(mask):
    """Squelettisation du masque"""
    return skeletonize(mask)

# %% [markdown]
# ## 6. Construction du Graphe et Calcul de la Longueur en Pixels

# %%
import networkx as nx
import math
import numpy as np

def skeleton_graph(skel):
    """Convertit le squelette en graphe NetworkX pour calculer la longueur"""
    coords = np.argwhere(skel)
    idx_map = { (int(y),int(x)): i for i,(y,x) in enumerate(coords) }
    G = nx.Graph()
    for (y,x), i in idx_map.items():
        G.add_node(i, pos=(y,x))
        for dy in (-1,0,1):
            for dx in (-1,0,1):
                if dy==0 and dx==0: continue
                ny, nx_ = y+dy, x+dx
                if (ny,nx_) in idx_map:
                    j = idx_map[(ny,nx_)]
                    dist = math.hypot(dy, dx)
                    G.add_edge(i,j,weight=dist)
    return G, coords

def find_endpoints(G):
    """Trouve les points terminaux (degré = 1) du graphe"""
    return [n for n,d in G.degree() if d==1]

def longest_path_length(G):
    """Calcule la longueur du chemin le plus long dans le graphe"""
    endpoints = find_endpoints(G)
    if not endpoints:
        return sum(d['weight'] for u,v,d in G.edges(data=True))/2
    maxlen = 0.0
    for i in range(len(endpoints)):
        lengths = nx.single_source_dijkstra_path_length(G, endpoints[i], weight='weight')
        for j in endpoints[i+1:]:
            if j in lengths and lengths[j] > maxlen:
                maxlen = lengths[j]
    return maxlen

# %% [markdown]
# ## 7. Conversion de la Longueur en Centimètres

# %%
def pixels_to_cm(longueur_pixels, longueur_objet_reel_cm, longueur_objet_pixels):
    """Convertit des pixels en cm en utilisant un objet de référence"""
    pixel_size_cm = longueur_objet_reel_cm / longueur_objet_pixels
    return longueur_pixels * pixel_size_cm

# %% [markdown]
# ## 8. Pipeline Complet : Traitement des Masques et Calcul des Longueurs

# %%
# --- Pipeline complet ---
train_masks_folder = "/content/dataset_masks/train"

# Paramètres de calibration (à ajuster selon vos images)
# Exemple : un câble de référence mesure 10 cm et fait 200 pixels sur l'image
LONGUEUR_OBJET_REEL_CM = 10
LONGUEUR_OBJET_PIXELS = 200

for mask_file in os.listdir(train_masks_folder):
    mask_path = os.path.join(train_masks_folder, mask_file)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    if mask is None:
        print(f"Fichier introuvable : {mask_path}")
        continue

    # Appliquer le pipeline
    mask_clean = preprocess_mask(mask)
    skel = skeletonize_mask(mask_clean)
    G, coords = skeleton_graph(skel)
    longueur_pixels = longest_path_length(G)

    # Conversion en cm
    longueur_cm = pixels_to_cm(longueur_pixels, LONGUEUR_OBJET_REEL_CM, LONGUEUR_OBJET_PIXELS)

    print(f"{mask_file} : longueur = {longueur_pixels:.2f} pixels ≈ {longueur_cm:.2f} cm")
# Out:
# photo-1761661842583_jpg.rf.4196021dd4f0a2bcf48a2cd1a1057894_mask.png : longueur = 409.12 pixels ≈ 20.46 cm
# photo-1761661127308_jpg.rf.984bde6a4b8f7722e1aa9b169b2458e9_mask.png : longueur = 937.08 pixels ≈ 46.85 cm
# photo-1761661263657_jpg.rf.e2e9c5b94a13646dccf938f3adfac8f0_mask.png : longueur = 1603.57 pixels ≈ 80.18 cm
# photo-1761661592850_jpg.rf.2275af26b8f9458c212df0f8f22036ef_mask.png : longueur = 693.04 pixels ≈ 34.65 cm
# photo-1761661736171_jpg.rf.0f602cf08ac62cc9584612bf542be3d7_mask.png : longueur = 1437.96 pixels ≈ 71.90 cm
# photo-1761661326741_jpg.rf.6157e39646375ba6620a713d10f66270_mask.png : longueur = 864.78 pixels ≈ 43.24 cm
# IMG_0878_JPG.rf.9f9dda1bd7f148657739f570bba6551a_mask.png : longueur = 783.18 pixels ≈ 39.16 cm
# photo-1761661699561_jpg.rf.74f4276e01a2ccf7abfe3d23c27b736c_mask.png : longueur = 1400.70 pixels ≈ 70.03 cm
# IMG_0881_JPG.rf.4ffbf7ca2179ab3f0390119a5361f280_mask.png : longueur = 1228.80 pixels ≈ 61.44 cm
# IMG_0879_JPG.rf.9c8d15760f01f367842f9203c85d4f12_mask.png : longueur = 832.64 pixels ≈ 41.63 cm
# photo-1761661633607_jpg.rf.4b1fd39ee07809cae60ab64d396e5a03_mask.png : longueur = 1072.05 pixels ≈ 53.60 cm
# photo-1761661519853_jpg.rf.359d1fa359a86f8ac6b5d53965f578da_mask.png : longueur = 809.84 pixels ≈ 40.49 cm
# photo-1761661822090_jpg.rf.51e17dc3e7a1badcecbd853d0cf0c8ff_mask.png : longueur = 433.68 pixels ≈ 21.68 cm
# photo-1761662542077_jpg.rf.8e99054c7388d387349d6d4d1a2ef7be_mask.png : longueur = 771.21 pixels ≈ 38.56 cm
# photo-1761661289202_jpg.rf.8d77229a3ef7c9d72f0fe44f81308570_mask.png : longueur = 1358.53 pixels ≈ 67.93 cm
# photo-1761661152885_jpg.rf.ea622ad8eb7921ac4eeb1856a6cb788a_mask.png : longueur = 1578.68 pixels ≈ 78.93 cm
# IMG_0883_JPG.rf.eed102c311bfda0961560cb742c58b28_mask.png : longueur = 763.75 pixels ≈ 38.19 cm
# photo-1761661794293_jpg.rf.62d0a254d97e91e50d8b953e95adea79_mask.png : longueur = 501.26 pixels ≈ 25.06 cm
# photo-1761661754850_jpg.rf.6605cccfe688c9a38e5f5863a650700e_mask.png : longueur = 1245.38 pixels ≈ 62.27 cm
# photo-1761661335540_jpg.rf.40305a2dd19f59d1d1c649da52037918_mask.png : longueur = 542.32 pixels ≈ 27.12 cm
# photo-1761661071197_jpg.rf.897f0265a45c4c5db8a5007a6a979826_mask.png : longueur = 2214.68 pixels ≈ 110.73 cm
# photo-1761661822090_jpg.rf.eb43682fb4426ca4040333b461d31314_mask.png : longueur = 459.75 pixels ≈ 22.99 cm
# photo-1761661406845_jpg.rf.2e088ddb54c436e53c845843a34e25e5_mask.png : longueur = 1298.93 pixels ≈ 64.95 cm
# photo-1761661263657_jpg.rf.153927cdf64c4cb535be4bf53549905d_mask.png : longueur = 1442.96 pixels ≈ 72.15 cm
# photo-1761661335540_jpg.rf.867ec4bdbeae27552fc06be65f567162_mask.png : longueur = 544.32 pixels ≈ 27.22 cm
# photo-1761661754850_jpg.rf.6ed975ac43fc6d684b61a48243800a9b_mask.png : longueur = 1189.39 pixels ≈ 59.47 cm
# IMG_0889_JPG.rf.e774608cb0946ed20730c6a6ae4a9f72_mask.png : longueur = 614.50 pixels ≈ 30.72 cm
# photo-1761661633607_jpg.rf.836ba5444ac96fc37424343fd3a08021_mask.png : longueur = 1170.79 pixels ≈ 58.54 cm
# photo-1761661398911_jpg.rf.1c0d1d0ef7827802f3189ff2b9f26b4f_mask.png : longueur = 1344.41 pixels ≈ 67.22 cm
# photo-1761661783120_jpg.rf.91a9b21066f25c13b6fc02901d7f5a96_mask.png : longueur = 384.78 pixels ≈ 19.24 cm
# IMG_0880_JPG.rf.38c5341eb42f6df237494a4c8a2776e6_mask.png : longueur = 981.74 pixels ≈ 49.09 cm
# photo-1761661408201_jpg.rf.cab436398b2f7b952b1d8bbe21a9b240_mask.png : longueur = 2277.74 pixels ≈ 113.89 cm
# photo-1761662522242_jpg.rf.eebdd34ac68254b4aac6523e0e4ec4b9_mask.png : longueur = 688.35 pixels ≈ 34.42 cm
# photo-1761661199657_jpg.rf.25bc17cc439cd73656ce334d138af91b_mask.png : longueur = 2145.45 pixels ≈ 107.27 cm
# photo-1761661286886_jpg.rf.262c235b1a73d897261e10ed0304efcc_mask.png : longueur = 1317.80 pixels ≈ 65.89 cm
# photo-1761661127308_jpg.rf.c1e3445676350dbe5e89f196ddccedea_mask.png : longueur = 887.28 pixels ≈ 44.36 cm
# IMG_0885_JPG.rf.16da295fdac2f2b7906d4a6df207ea93_mask.png : longueur = 637.40 pixels ≈ 31.87 cm
# photo-1761662542077_jpg.rf.0cceec82c675f3add32c2aa39711340b_mask.png : longueur = 779.80 pixels ≈ 38.99 cm
# photo-1761661084109_jpg.rf.ad5e7c8bc9fa4b8db442890104be32cc_mask.png : longueur = 892.02 pixels ≈ 44.60 cm
# photo-1761661827255_jpg.rf.565368061aa2cc7090248a54fd5dcdae_mask.png : longueur = 473.37 pixels ≈ 23.67 cm
# photo-1761660929689_jpg.rf.597adea55708c995748a5b15fd00ad9d_mask.png : longueur = 1886.26 pixels ≈ 94.31 cm
# photo-1761661652765_jpg.rf.9b2608cdca37f2d502f5a1a0e7f8a9eb_mask.png : longueur = 1928.66 pixels ≈ 96.43 cm
# IMG_0885_JPG.rf.36e2eb31deae91114303447f03099464_mask.png : longueur = 632.09 pixels ≈ 31.60 cm
# photo-1761661065099_jpg.rf.2191d0f7e970ac5edb1c2a5c61a16e07_mask.png : longueur = 1596.28 pixels ≈ 79.81 cm
# photo-1761661335540_jpg.rf.2a2c4c6091e41cc5b647df8384b0e9ea_mask.png : longueur = 603.43 pixels ≈ 30.17 cm
# photo-1761661199657_jpg.rf.b45bfe15ee2318fe5a4606fddfbf3fe4_mask.png : longueur = 2229.49 pixels ≈ 111.47 cm
# photo-1761662444633_jpg.rf.851c1df8c7ecadcc833955ebf34a8103_mask.png : longueur = 1934.74 pixels ≈ 96.74 cm
# photo-1761662444633_jpg.rf.e294facfc531cd0c5677b503111584fe_mask.png : longueur = 2001.02 pixels ≈ 100.05 cm
# photo-1761660595564_jpg.rf.c20a168f870566fad64ae93d319fae6c_mask.png : longueur = 1931.28 pixels ≈ 96.56 cm
# photo-1761662078835_jpg.rf.a2bf5499c47391f36e99e09b29fa44d4_mask.png : longueur = 2134.16 pixels ≈ 106.71 cm
# photo-1761662001655_jpg.rf.901bfd327157dbe7633a4d94efac2fdb_mask.png : longueur = 1305.26 pixels ≈ 65.26 cm
# photo-1761661723881_jpg.rf.17a057cbb039bbab6443dccf35c13cdb_mask.png : longueur = 1245.22 pixels ≈ 62.26 cm
# photo-1761661736171_jpg.rf.b92884bf328b0f63da5ccc32400f6f9a_mask.png : longueur = 1502.66 pixels ≈ 75.13 cm
# photo-1761661633607_jpg.rf.e1044446683c1b4ce1f15f40628c5841_mask.png : longueur = 1054.39 pixels ≈ 52.72 cm
# photo-1761661842583_jpg.rf.cbd385bba053a5e1da9b874a83cbe08f_mask.png : longueur = 453.26 pixels ≈ 22.66 cm
# IMG_0890_JPG.rf.39c74a309ac74b500988a26b73cff5b4_mask.png : longueur = 685.85 pixels ≈ 34.29 cm
# photo-1761662592683_jpg.rf.e91899b75f477bfd97bf01d03822113b_mask.png : longueur = 1160.64 pixels ≈ 58.03 cm
# photo-1761662592683_jpg.rf.170f9bb48758a9c323b79f282a824ff4_mask.png : longueur = 1181.36 pixels ≈ 59.07 cm
# photo-1761661408201_jpg.rf.69e0e6f4f9dcbcb9a042ee94b117ff05_mask.png : longueur = 2256.74 pixels ≈ 112.84 cm
# photo-1761662522242_jpg.rf.cfe36cfdedd9b9d4c89407a1ae529134_mask.png : longueur = 688.01 pixels ≈ 34.40 cm
# photo-1761661893029_jpg.rf.6ca79013e33b33ff2adc430cdc531faa_mask.png : longueur = 2258.72 pixels ≈ 112.94 cm
# photo-1761661321075_jpg.rf.2213820f825daeb5b438c1e7b948a77e_mask.png : longueur = 1025.65 pixels ≈ 51.28 cm
# IMG_0883_JPG.rf.23b2f2e2c37641efc658e8b3c225574c_mask.png : longueur = 692.94 pixels ≈ 34.65 cm
# photo-1761661736171_jpg.rf.67fccb00e2977ef40b9fb69329408ac9_mask.png : longueur = 1461.34 pixels ≈ 73.07 cm
# photo-1761662078835_jpg.rf.c1183d0c69e034b6b66d45241b62879e_mask.png : longueur = 2197.55 pixels ≈ 109.88 cm
# photo-1761662033363_jpg.rf.dc7b374c2458a7986c684bbac9765889_mask.png : longueur = 2432.69 pixels ≈ 121.63 cm
# IMG_0890_JPG.rf.b03c25d5aa5078eb4fadbfdebb2a971a_mask.png : longueur = 630.32 pixels ≈ 31.52 cm
# photo-1761661252730_jpg.rf.1799b680f12cf6f61c2c30c4ddeec838_mask.png : longueur = 1276.74 pixels ≈ 63.84 cm
# IMG_0892_JPG.rf.b4eab2dc3f884f71f1fb6f6b2e8df15b_mask.png : longueur = 630.36 pixels ≈ 31.52 cm
# IMG_0882_JPG.rf.113613a0f37ce9097f09935809d89cb6_mask.png : longueur = 1273.71 pixels ≈ 63.69 cm
# photo-1761661556024_jpg.rf.0dec26fedb98dd5b8d5fc7fbc45a7d31_mask.png : longueur = 2013.39 pixels ≈ 100.67 cm
# photo-1761661556024_jpg.rf.fd56cc9dfc114b370c5bdf2eb4acb06a_mask.png : longueur = 2329.67 pixels ≈ 116.48 cm
# photo-1761662444633_jpg.rf.af0fc004bae83e2bd92235c89cee813f_mask.png : longueur = 2119.17 pixels ≈ 105.96 cm
# photo-1761661187957_jpg.rf.4c11d164f0b0886d2aba85c916a7f59b_mask.png : longueur = 1493.27 pixels ≈ 74.66 cm
# photo-1761661187957_jpg.rf.b5870e0fef608ce0a5b9bc2727189b79_mask.png : longueur = 1018.85 pixels ≈ 50.94 cm
# IMG_0886_JPG.rf.9730e2b7d555069c87ba1e9ad403cafc_mask.png : longueur = 850.06 pixels ≈ 42.50 cm
# photo-1761661618705_jpg.rf.4cc479c2ed78a040c963b60707bf4621_mask.png : longueur = 1163.40 pixels ≈ 58.17 cm
# photo-1761661555523_jpg.rf.d45b6ef26e9bf29f1436364585f3c592_mask.png : longueur = 1047.85 pixels ≈ 52.39 cm
# photo-1761661256153_jpg.rf.d0cff87738212876947dc802638ed43d_mask.png : longueur = 1297.99 pixels ≈ 64.90 cm
# photo-1761661827255_jpg.rf.eddfbf58ecd9ed4cd3e7236e7fad3231_mask.png : longueur = 469.89 pixels ≈ 23.49 cm
# photo-1761661252730_jpg.rf.dc23e7018f64eab79187e9e5ecf20549_mask.png : longueur = 1126.21 pixels ≈ 56.31 cm
# photo-1761661723881_jpg.rf.3d651e476ae1552ef3367abb8d5b2412_mask.png : longueur = 811.65 pixels ≈ 40.58 cm
# photo-1761661555523_jpg.rf.3b15cfdd55a10e1a75b2609c1b1a3602_mask.png : longueur = 1093.48 pixels ≈ 54.67 cm
# photo-1761661321075_jpg.rf.3d19b272d5046f049bced882503c31f0_mask.png : longueur = 1372.00 pixels ≈ 68.60 cm
# photo-1761661228274_jpg.rf.29d9584cc68dd0b9842539eeb35fc63b_mask.png : longueur = 2096.91 pixels ≈ 104.85 cm
# photo-1761661393641_jpg.rf.cced06cc6a0e1caca28f6b9186d75705_mask.png : longueur = 1234.97 pixels ≈ 61.75 cm
# photo-1761662033363_jpg.rf.b0f6419eb2e9ab83dd916c7586d40173_mask.png : longueur = 2375.99 pixels ≈ 118.80 cm
# photo-1761662522242_jpg.rf.33c4d2d571cd796f6982e7717dd91875_mask.png : longueur = 693.01 pixels ≈ 34.65 cm
# IMG_0875_JPG.rf.39cab6dc13d6000d45dca5c5cca876c9_mask.png : longueur = 876.68 pixels ≈ 43.83 cm
# photo-1761662078835_jpg.rf.faa9fa326a204b045aad44a03e3ededa_mask.png : longueur = 2163.41 pixels ≈ 108.17 cm
# IMG_0890_JPG.rf.98fbd01eb94f69a8f442e97c0f45b2d8_mask.png : longueur = 730.82 pixels ≈ 36.54 cm
# photo-1761662201651_jpg.rf.ee59c95af50e24df23ab61d8eb860922_mask.png : longueur = 1102.91 pixels ≈ 55.15 cm
# photo-1761661152885_jpg.rf.f9bba16522e44b55076814ceaa5d01f7_mask.png : longueur = 1673.83 pixels ≈ 83.69 cm
# photo-1761661618705_jpg.rf.0b37c12fd35ac67d96f09717760829eb_mask.png : longueur = 2140.87 pixels ≈ 107.04 cm
# IMG_0881_JPG.rf.207134f519c4246bce0d6b0622d935dc_mask.png : longueur = 949.68 pixels ≈ 47.48 cm
# photo-1761661115089_jpg.rf.2cdaeaac4f3a5462a20bcccea6321076_mask.png : longueur = 1575.15 pixels ≈ 78.76 cm
# photo-1761661084109_jpg.rf.4c218b8f3acd7e4bd4d375c93e99eab6_mask.png : longueur = 1205.82 pixels ≈ 60.29 cm
# photo-1761661393641_jpg.rf.5569b090d91b09b8622e0fbca4014677_mask.png : longueur = 753.74 pixels ≈ 37.69 cm
# photo-1761661256153_jpg.rf.2e71d1df885f5637d33c4797d66bd28e_mask.png : longueur = 1392.76 pixels ≈ 69.64 cm
# photo-1761662542077_jpg.rf.2691e55bd170bd5ae4b942bb66a74e8a_mask.png : longueur = 791.52 pixels ≈ 39.58 cm
# IMG_0882_JPG.rf.50aa2d6e7bb275bf8a226d790855b2f0_mask.png : longueur = 2139.64 pixels ≈ 106.98 cm
# photo-1761661105573_jpg.rf.73ff34669fa3c61a8b2bc93fe4cc9125_mask.png : longueur = 1771.23 pixels ≈ 88.56 cm
# photo-1761661406845_jpg.rf.7a021a01a624bb4a49525e27ef18e503_mask.png : longueur = 1008.19 pixels ≈ 50.41 cm
# photo-1761661065099_jpg.rf.adc857f75681b3eecdd49c28eb93510c_mask.png : longueur = 1690.98 pixels ≈ 84.55 cm
# photo-1761661555523_jpg.rf.a07b310b4c5e7f8d7d80e37f21460f9d_mask.png : longueur = 1038.92 pixels ≈ 51.95 cm
# photo-1761661220347_jpg.rf.8b3d703454db553587b63fb58d30d593_mask.png : longueur = 1134.13 pixels ≈ 56.71 cm
# IMG_0886_JPG.rf.863ab828ba6f5950db80788ba037184e_mask.png : longueur = 827.72 pixels ≈ 41.39 cm
# photo-1761661220347_jpg.rf.c9b09ad1eacc4dc7e2ba08b05fbbe98f_mask.png : longueur = 1369.76 pixels ≈ 68.49 cm
# photo-1761661556024_jpg.rf.1da4971b04c7d0da42fde53c6393a981_mask.png : longueur = 2385.78 pixels ≈ 119.29 cm
# photo-1761661326741_jpg.rf.05d198896b5c9c25742a351139ce9d9e_mask.png : longueur = 923.72 pixels ≈ 46.19 cm
# photo-1761661893029_jpg.rf.ec2b9324fb317e8d75320c04e3b8d7f4_mask.png : longueur = 1168.30 pixels ≈ 58.42 cm
# photo-1761662485309_jpg.rf.45f1eaea9897a3e313e9d13ee931f9a9_mask.png : longueur = 1238.17 pixels ≈ 61.91 cm
# photo-1761661816672_jpg.rf.48467f3eba72ff322235db54f56eff22_mask.png : longueur = 529.58 pixels ≈ 26.48 cm
# photo-1761661172878_jpg.rf.6065bbc4495993fd66ae0cc199aa74eb_mask.png : longueur = 1178.80 pixels ≈ 58.94 cm
# photo-1761661652765_jpg.rf.8cb2a38366ebae840125f6989e36ecb7_mask.png : longueur = 1845.62 pixels ≈ 92.28 cm
# photo-1761660929689_jpg.rf.51bd44e258f93e9cbcf21ed8b35a9d20_mask.png : longueur = 1999.65 pixels ≈ 99.98 cm
# photo-1761661842583_jpg.rf.61407568bddcd42041f3c2c1297110ce_mask.png : longueur = 453.68 pixels ≈ 22.68 cm
# photo-1761661542164_jpg.rf.b1b55d2a7cfb3533c5d80300a56358e3_mask.png : longueur = 508.45 pixels ≈ 25.42 cm
# photo-1761661705355_jpg.rf.52fe9097985ddd243adc5f008f0963a2_mask.png : longueur = 1387.84 pixels ≈ 69.39 cm
# photo-1761661748916_jpg.rf.d848cb07b5bdd178507058dfea43ba5f_mask.png : longueur = 1036.10 pixels ≈ 51.81 cm
# IMG_0880_JPG.rf.fb48be57a33992d25f1b01faf9c9802f_mask.png : longueur = 1061.27 pixels ≈ 53.06 cm
# IMG_0883_JPG.rf.747e1d3104c1464656b60a846b6c7b83_mask.png : longueur = 654.80 pixels ≈ 32.74 cm
# photo-1761661398911_jpg.rf.35d6fc55cc30961c3aedb01fb82fe058_mask.png : longueur = 1283.71 pixels ≈ 64.19 cm
# IMG_0886_JPG.rf.13aed568526126c8dd267cdfd9aee9d9_mask.png : longueur = 807.13 pixels ≈ 40.36 cm
# photo-1761661389552_jpg.rf.397b9d18dcead5ed555b3bd478808665_mask.png : longueur = 1940.91 pixels ≈ 97.05 cm
# photo-1761662001655_jpg.rf.91f7abee257827968b64bdda4edb1a0e_mask.png : longueur = 1321.57 pixels ≈ 66.08 cm
# photo-1761661829792_jpg.rf.41effe260fab16c45517c44338b13cce_mask.png : longueur = 1206.73 pixels ≈ 60.34 cm
# IMG_0888_JPG.rf.0611cb4cae2bcf935ccec5628550356e_mask.png : longueur = 2191.71 pixels ≈ 109.59 cm
# photo-1761661519853_jpg.rf.2d430a642a6a709010c9d42f58942027_mask.png : longueur = 818.33 pixels ≈ 40.92 cm
# photo-1761661389552_jpg.rf.24f46aa77e62522b40703e9dc6a2c03d_mask.png : longueur = 2124.62 pixels ≈ 106.23 cm
# photo-1761660595564_jpg.rf.f043fac7e3238f39f570e378ad78aefd_mask.png : longueur = 1859.86 pixels ≈ 92.99 cm
# photo-1761661408201_jpg.rf.140b5d127a9632ff786a3606cee303d3_mask.png : longueur = 2119.17 pixels ≈ 105.96 cm
# photo-1761661727302_jpg.rf.cd906f78f1cea0905fa43ec04dea95f0_mask.png : longueur = 1276.58 pixels ≈ 63.83 cm
# photo-1761661677338_jpg.rf.1e457a045344547730139e8c19a246e6_mask.png : longueur = 1169.41 pixels ≈ 58.47 cm
# photo-1761661699561_jpg.rf.758fd70d91c7034160fa2dc406e3909f_mask.png : longueur = 1430.60 pixels ≈ 71.53 cm
# photo-1761661705355_jpg.rf.067986644483550e9a3fa0952ebbf512_mask.png : longueur = 991.82 pixels ≈ 49.59 cm
# photo-1761661220347_jpg.rf.d0e304718dbf7d10027a0d2cdeb75037_mask.png : longueur = 1366.90 pixels ≈ 68.34 cm
# photo-1761661252730_jpg.rf.30f5d093e2bc93cbce9edccf383b156e_mask.png : longueur = 1421.14 pixels ≈ 71.06 cm
# photo-1761661592850_jpg.rf.06a0a91ba3dde681e0cf556c3ca56c81_mask.png : longueur = 653.83 pixels ≈ 32.69 cm
# photo-1761661519853_jpg.rf.83c4ca4889560a698f2ec881c0715062_mask.png : longueur = 847.88 pixels ≈ 42.39 cm
# IMG_0878_JPG.rf.b0155873ec160b0b4605dac73df6dbf2_mask.png : longueur = 788.11 pixels ≈ 39.41 cm
# photo-1761661105573_jpg.rf.f1e8cf5dad808bb8a8afdcaeca4bdb95_mask.png : longueur = 1243.17 pixels ≈ 62.16 cm
# photo-1761662201651_jpg.rf.bb0024fc77f4cfac4f9528f8f380dc26_mask.png : longueur = 1026.94 pixels ≈ 51.35 cm
# photo-1761661321075_jpg.rf.1c38cec4295b2aac117f92dee34b739e_mask.png : longueur = 758.74 pixels ≈ 37.94 cm
# photo-1761661783120_jpg.rf.034858d5e14ab46a17cbba273f4f3130_mask.png : longueur = 399.61 pixels ≈ 19.98 cm
# photo-1761661152885_jpg.rf.11773288885ea359700b1ac644776188_mask.png : longueur = 1428.07 pixels ≈ 71.40 cm
# photo-1761661286886_jpg.rf.91ce9f4813d2ab9989a1bb135d394074_mask.png : longueur = 1395.35 pixels ≈ 69.77 cm
# photo-1761661652765_jpg.rf.a67d4f616780a2591c8a246f2682c1fe_mask.png : longueur = 1742.36 pixels ≈ 87.12 cm
# photo-1761661583144_jpg.rf.8db64ab3f1ccb6a14ee854606314626e_mask.png : longueur = 654.81 pixels ≈ 32.74 cm
# photo-1761661583144_jpg.rf.0d01bbe56577df0dfbdce6f7a8500b13_mask.png : longueur = 640.01 pixels ≈ 32.00 cm
# photo-1761661723881_jpg.rf.2d267cb794624ab3e1d4932486648730_mask.png : longueur = 1258.27 pixels ≈ 62.91 cm
# photo-1761661398911_jpg.rf.a39d8a325c9c77029ca9aed4fad577bb_mask.png : longueur = 1270.71 pixels ≈ 63.54 cm
# photo-1761661170177_jpg.rf.dcd0742df386b9cbb7be68160384c396_mask.png : longueur = 2021.16 pixels ≈ 101.06 cm
# photo-1761661172878_jpg.rf.79b55112e216ff644c84cb743756c7e5_mask.png : longueur = 1297.64 pixels ≈ 64.88 cm
# photo-1761662557093_jpg.rf.eb9c49c13d39af8607ad9a8e5b42e1db_mask.png : longueur = 783.55 pixels ≈ 39.18 cm
# photo-1761661286886_jpg.rf.7b6099cf69ba7be55b39d2420e5e24d1_mask.png : longueur = 1327.51 pixels ≈ 66.38 cm
# photo-1761661748916_jpg.rf.ae2ec11e5f72ffb4e3c2e7debc9ccc98_mask.png : longueur = 1008.48 pixels ≈ 50.42 cm
# photo-1761661822090_jpg.rf.e84840a2a5aed691b4e49ab7c77e7705_mask.png : longueur = 465.58 pixels ≈ 23.28 cm
# photo-1761662592683_jpg.rf.69403fc40b739e2bca4ce5f7377d27c7_mask.png : longueur = 1160.64 pixels ≈ 58.03 cm
# photo-1761661827255_jpg.rf.241d3202f912a61dfd899721d68d5ff4_mask.png : longueur = 485.86 pixels ≈ 24.29 cm
# photo-1761661256153_jpg.rf.d308f61ea222a792fee9d5e790a6e6ab_mask.png : longueur = 1326.82 pixels ≈ 66.34 cm
# photo-1761661172878_jpg.rf.1ff4dac41d8d9aaa4af93e64b0affcb9_mask.png : longueur = 1167.48 pixels ≈ 58.37 cm
# photo-1761661406845_jpg.rf.fbcf7230eaa88617d33b2c98a78b1a83_mask.png : longueur = 1239.09 pixels ≈ 61.95 cm
# photo-1761661829792_jpg.rf.7dc08750749c6a2acfdd580dfd7110cb_mask.png : longueur = 1818.39 pixels ≈ 90.92 cm
# photo-1761661748916_jpg.rf.7cf504c91e707e7a28ec0f1cea5ddde5_mask.png : longueur = 997.62 pixels ≈ 49.88 cm
# IMG_0887_JPG.rf.d8ba566140c254183e7a0a7289b1051a_mask.png : longueur = 1289.53 pixels ≈ 64.48 cm
# photo-1761661228274_jpg.rf.3bbca313504cad4275ef69df08499cac_mask.png : longueur = 2079.33 pixels ≈ 103.97 cm
# photo-1761661816672_jpg.rf.c550cd87f104a48dfa0e35e8e063cb01_mask.png : longueur = 475.02 pixels ≈ 23.75 cm
# IMG_0874_JPG.rf.97b287adb0a0ff4d3ec2fa4081d51331_mask.png : longueur = 1069.84 pixels ≈ 53.49 cm
# photo-1761661393641_jpg.rf.80f0252c3411150dc6a4dde535454340_mask.png : longueur = 1192.17 pixels ≈ 59.61 cm
# photo-1761661263657_jpg.rf.f96208c8dc1f12077cbe0eccad0df10f_mask.png : longueur = 1441.31 pixels ≈ 72.07 cm
# IMG_0881_JPG.rf.94b35226967589aca6d1fa3edc8756b4_mask.png : longueur = 854.08 pixels ≈ 42.70 cm
# IMG_0889_JPG.rf.a46cb36ef7ae8a161fd0b0ca90ec3e32_mask.png : longueur = 624.67 pixels ≈ 31.23 cm
# photo-1761661699561_jpg.rf.fd3936ff122e89560453420ad9caaedb_mask.png : longueur = 1429.50 pixels ≈ 71.47 cm
# photo-1761661170177_jpg.rf.1bf16c1f6e0098c88335a61a746d08bf_mask.png : longueur = 1892.38 pixels ≈ 94.62 cm
# IMG_0888_JPG.rf.cbe807dc43393fc76e048fd018d081fc_mask.png : longueur = 2242.58 pixels ≈ 112.13 cm
# photo-1761662001655_jpg.rf.45a613974ba8ae93af9bf484e12b0d1c_mask.png : longueur = 1376.03 pixels ≈ 68.80 cm
# photo-1761661115089_jpg.rf.c289442eea1826d1f3f98760ebf40a47_mask.png : longueur = 1569.70 pixels ≈ 78.48 cm
# IMG_0892_JPG.rf.0016c4e06e9b54736a56c36c7e941deb_mask.png : longueur = 631.15 pixels ≈ 31.56 cm
# photo-1761661618705_jpg.rf.757b18704b5c58c86638d79f7836d1e1_mask.png : longueur = 2277.89 pixels ≈ 113.89 cm
# photo-1761662485309_jpg.rf.4e6fef770d98d6ec244700d4208ac5d2_mask.png : longueur = 1296.08 pixels ≈ 64.80 cm
# photo-1761661105573_jpg.rf.29ac5c60bd171c6480b6e068583c668a_mask.png : longueur = 1669.08 pixels ≈ 83.45 cm
# photo-1761661583144_jpg.rf.5c04677b9fdb7de35455e0694f8f1e69_mask.png : longueur = 664.05 pixels ≈ 33.20 cm
# photo-1761661727302_jpg.rf.36453a72abff627984a423da84565455_mask.png : longueur = 1332.86 pixels ≈ 66.64 cm
# photo-1761661542164_jpg.rf.ff72d28102bb35ba6a4233f3d7d15cdc_mask.png : longueur = 553.07 pixels ≈ 27.65 cm
# photo-1761661592850_jpg.rf.cb87486ae5de74fa0a951a4152a9fe1c_mask.png : longueur = 692.80 pixels ≈ 34.64 cm
# photo-1761661794293_jpg.rf.16918ae93f8be4d3875bb933ca1788e2_mask.png : longueur = 456.29 pixels ≈ 22.81 cm
# photo-1761661829792_jpg.rf.20234ff229529030673af4b98cb9d4fc_mask.png : longueur = 610.35 pixels ≈ 30.52 cm
# IMG_0877_JPG.rf.a7cb49af5239fcf0781bc4ee5d0958d7_mask.png : longueur = 921.02 pixels ≈ 46.05 cm
# IMG_0874_JPG.rf.b64a76d2a218d0aee14897658d94d77d_mask.png : longueur = 988.90 pixels ≈ 49.45 cm
# IMG_0875_JPG.rf.95475b317202ac26c376ab8e8096a0a3_mask.png : longueur = 902.79 pixels ≈ 45.14 cm
# IMG_0875_JPG.rf.54e8feceffa88bc8ed56c7bc4bbbadb8_mask.png : longueur = 875.51 pixels ≈ 43.78 cm
# photo-1761661705355_jpg.rf.311f5709b7fe65d08fba4280a0b046be_mask.png : longueur = 1383.70 pixels ≈ 69.18 cm
# IMG_0879_JPG.rf.226f33555c13f3e51c4d1b531fb761b1_mask.png : longueur = 804.91 pixels ≈ 40.25 cm
# photo-1761661542164_jpg.rf.b476689624f190693e66a5c8f27f9f81_mask.png : longueur = 523.59 pixels ≈ 26.18 cm
# photo-1761661065099_jpg.rf.a0c6b8bbec52a59e2d9848739fd37169_mask.png : longueur = 2121.91 pixels ≈ 106.10 cm
# photo-1761661275569_jpg.rf.8ca1feedb026cdda3a1f46ec21601a52_mask.png : longueur = 1403.96 pixels ≈ 70.20 cm
# photo-1761661326741_jpg.rf.4afde081cb7d403e710326184c4497e4_mask.png : longueur = 915.41 pixels ≈ 45.77 cm
# photo-1761661170177_jpg.rf.41686c7349e77ca196454356c9da402c_mask.png : longueur = 1862.51 pixels ≈ 93.13 cm
# photo-1761661289202_jpg.rf.4b8626fc89f09186abeab6cb44b03edd_mask.png : longueur = 1341.80 pixels ≈ 67.09 cm
# photo-1761661677338_jpg.rf.bb4c2385adf8e9dffbf3233500296afd_mask.png : longueur = 1125.22 pixels ≈ 56.26 cm
# IMG_0882_JPG.rf.f4f901a895f35083648f5dd0cd1fb3ff_mask.png : longueur = 2004.79 pixels ≈ 100.24 cm
# IMG_0880_JPG.rf.434c852cdf8a31032d1c33bdb9f0cfa7_mask.png : longueur = 963.99 pixels ≈ 48.20 cm
# photo-1761661071197_jpg.rf.eba0f2773387664e49e89907ecab0067_mask.png : longueur = 1589.28 pixels ≈ 79.46 cm
# photo-1761661816672_jpg.rf.5cc814a8ef03d66dd87d8f9a2195e3a5_mask.png : longueur = 511.33 pixels ≈ 25.57 cm
# IMG_0888_JPG.rf.dd2f8e0babccbf477431ba9899588bd2_mask.png : longueur = 2088.62 pixels ≈ 104.43 cm
# IMG_0877_JPG.rf.3decf2b99f6552eb522c41e9a3f9b8f9_mask.png : longueur = 825.52 pixels ≈ 41.28 cm
# photo-1761661071197_jpg.rf.02f79f936ef5f5d924083f6acb9dbc55_mask.png : longueur = 2228.20 pixels ≈ 111.41 cm
# photo-1761662033363_jpg.rf.b72db84a211494a34c9c8150713f1f5f_mask.png : longueur = 2545.12 pixels ≈ 127.26 cm
# IMG_0878_JPG.rf.aa9ca45637f76364657ce0004b77ba10_mask.png : longueur = 853.88 pixels ≈ 42.69 cm
# IMG_0877_JPG.rf.24857c937425ae1dd6dc60c5164a875f_mask.png : longueur = 880.32 pixels ≈ 44.02 cm
# photo-1761660929689_jpg.rf.a630f33f9143e9e7b58705d1290077ca_mask.png : longueur = 2011.03 pixels ≈ 100.55 cm
# photo-1761661727302_jpg.rf.295bfa74b0f869fdac25ff7a7a33313e_mask.png : longueur = 1404.12 pixels ≈ 70.21 cm
# IMG_0879_JPG.rf.1e5b132926d8bb9366213853f2e531fd_mask.png : longueur = 776.52 pixels ≈ 38.83 cm
# photo-1761661127308_jpg.rf.640ef58b2ee44bdfd1282658063ebbad_mask.png : longueur = 992.84 pixels ≈ 49.64 cm
# photo-1761661187957_jpg.rf.ebf1c7775b3945b98cdb42263d18a91e_mask.png : longueur = 1395.60 pixels ≈ 69.78 cm
# IMG_0889_JPG.rf.661fab9b56790d93c6ec06382e6bd1d8_mask.png : longueur = 613.22 pixels ≈ 30.66 cm
# IMG_0887_JPG.rf.3ad3a09b59b0051a90d19a1138d557e5_mask.png : longueur = 2530.33 pixels ≈ 126.52 cm
# photo-1761661783120_jpg.rf.9e9c3442ee9bb21234b369baf5bf41d7_mask.png : longueur = 374.12 pixels ≈ 18.71 cm
# photo-1761661084109_jpg.rf.1c87eccb21c420a18db6afac7e340565_mask.png : longueur = 933.99 pixels ≈ 46.70 cm
# IMG_0885_JPG.rf.68d5728064ff779629fa005c5f2a5d19_mask.png : longueur = 634.36 pixels ≈ 31.72 cm
# photo-1761661389552_jpg.rf.d57cbdc51359f9b819ea552cd1b3ea19_mask.png : longueur = 2075.30 pixels ≈ 103.77 cm
# photo-1761661754850_jpg.rf.d7ea4a8827f863904ede969c57530ecc_mask.png : longueur = 1314.84 pixels ≈ 65.74 cm
# photo-1761662557093_jpg.rf.4f5b94314378a3078ea05855883025c3_mask.png : longueur = 739.35 pixels ≈ 36.97 cm
# photo-1761661228274_jpg.rf.99b0ffa282bb7c748dcc0ee617ac0d4a_mask.png : longueur = 1358.43 pixels ≈ 67.92 cm
# photo-1761661794293_jpg.rf.24b3af4bfd2689e88f4aee4107d72d3d_mask.png : longueur = 483.43 pixels ≈ 24.17 cm
# photo-1761661893029_jpg.rf.2f0cb964ff70fc6a0b48cf58e143a63b_mask.png : longueur = 2310.32 pixels ≈ 115.52 cm
# photo-1761661275569_jpg.rf.fcf7ed4e2953951fdbd3cbcc2668f1ad_mask.png : longueur = 1490.59 pixels ≈ 74.53 cm
# photo-1761661677338_jpg.rf.5769443485cfca3f73786fd0d51888c3_mask.png : longueur = 918.57 pixels ≈ 45.93 cm
# photo-1761661199657_jpg.rf.066a55cec9ae612f680e258728ab83f8_mask.png : longueur = 2044.95 pixels ≈ 102.25 cm
# photo-1761660595564_jpg.rf.34d0a49e06496fba98b8d8ed6d479771_mask.png : longueur = 1197.79 pixels ≈ 59.89 cm
# photo-1761661289202_jpg.rf.14cb6508acdeb19b560592047d5bb630_mask.png : longueur = 1320.53 pixels ≈ 66.03 cm
# IMG_0887_JPG.rf.05096a6f17f208d329c216963e3c0282_mask.png : longueur = 2393.39 pixels ≈ 119.67 cm
# photo-1761662485309_jpg.rf.b7c07407d6603e5f1cb920eeb199f6ef_mask.png : longueur = 1229.48 pixels ≈ 61.47 cm
# photo-1761662201651_jpg.rf.9903b5bbd094dfa4599a7d6b9db15b4a_mask.png : longueur = 1914.87 pixels ≈ 95.74 cm
# photo-1761662557093_jpg.rf.d0fd493f5d4814796999faeaa321dc4c_mask.png : longueur = 693.72 pixels ≈ 34.69 cm
# photo-1761661115089_jpg.rf.5bb65108ee2e30fa4414a175e58f6d3e_mask.png : longueur = 1404.54 pixels ≈ 70.23 cm
# IMG_0874_JPG.rf.bf6ab5dadc6470cd17ff02c8a8fedd4f_mask.png : longueur = 1000.49 pixels ≈ 50.02 cm
# photo-1761661275569_jpg.rf.a15d71f201475e65e7f1245a961ed17f_mask.png : longueur = 1414.31 pixels ≈ 70.72 cm
# IMG_0892_JPG.rf.021b641857b7010c8888cc1d45d03240_mask.png : longueur = 600.25 pixels ≈ 30.01 cm

# %%
import matplotlib.pyplot as plt

# Critères de qualité
LONGUEUR_MIN_OK = 22  # cm
LONGUEUR_MAX_OK = 60  # cm

# --- Pipeline avec affichage ---
for mask_file in os.listdir(train_masks_folder):
    mask_path = os.path.join(train_masks_folder, mask_file)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    if mask is None:
        print(f"Fichier introuvable : {mask_path}")
        continue

    # Appliquer le pipeline
    mask_clean = preprocess_mask(mask)
    skel = skeletonize_mask(mask_clean)
    G, coords = skeleton_graph(skel)
    longueur_pixels = longest_path_length(G)
    longueur_cm = pixels_to_cm(longueur_pixels, LONGUEUR_OBJET_REEL_CM, LONGUEUR_OBJET_PIXELS)

    # Déterminer si le câble est OK ou DÉFECTUEUX
    if LONGUEUR_MIN_OK <= longueur_cm <= LONGUEUR_MAX_OK:
        statut = "OK"
        couleur_titre = "green"
    else:
        statut = "DÉFECTUEUX"
        couleur_titre = "red"

    # --- Affichage ---
    plt.figure(figsize=(8,8))
    plt.imshow(mask, cmap='gray')
    plt.imshow(skel, cmap='hot', alpha=0.7)  # superpose le squelette en rouge
    plt.title(f"{mask_file}\nLongueur = {longueur_pixels:.2f} pixels ≈ {longueur_cm:.2f} cm\nStatut: {statut}",
              color=couleur_titre, fontsize=14, fontweight='bold')
    plt.axis('off')
    plt.show()

    print(f"{mask_file} : {longueur_cm:.2f} cm - {statut}")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
